# %%
#1
In object-oriented programming (OOP), a class is a blueprint or template for creating objects. It defines a set of attributes and methods that the objects will have. An object, on the other hand, is an instance of a class. It is a specific realization of the class with its own set of values for the attributes defined by the class and its own implementation of the methods defined by the class.
example:
Let's take an example of a class called Person to understand this concept better. The Person class can have attributes such as name, age, and gender, and methods such as get_name(), get_age(), and get_gender(). We can create objects of the Person class with specific values for the attributes.
class Person:
    def __init__(self, name, age, gender):
        self.name = name
        self.age = age
        self.gender = gender
        
    def get_name(self):
        return self.name
    
    def get_age(self):
        return self.age
    
    def get_gender(self):
        return self.gender

# create objects of the Person class
person1 = Person('Aakash', 27, 'Male')
person2 = Person('Sonali', 29, 'Female')

# %%
#2
Encapsulation, Abstraction, Inheritance, Polymorphism

# %%
#3
The __init__() function is a special method in Python classes that is used to initialize an instance of a class. It is executed automatically when a new object is created and allows us to set initial values for the object's attributes. In other words, __init__() initializes the state of an object by assigning values to its attributes.
example:
class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

car1 = Car('Suzuki', 'Alto', 2015)

# %%
#4
In object-oriented programming, self is a reference to the current instance of a class. It is used within the class definition to refer to the attributes and methods of the instance.

# %%
#5
Inheritance is a mechanism in object-oriented programming that allows one class (called the subclass or derived class) to inherit properties and methods from another class (called the superclass or base class). The subclass can then add or override methods and properties, and may also define additional properties and methods of its own.
There are four types of inheritance in Python:

Single Inheritance: In single inheritance, a subclass inherits from a single superclass. For example:
class Animal:
    def __init__(self, name):
        self.name = name
        
    def speak(self):
        pass

class Dog(Animal):
    def speak(self):
        return "Woof!"

class Cat(Animal):
    def speak(self):
        return "Meow!"

Multiple Inheritance: In multiple inheritance, a subclass inherits from two or more superclasses. For example:
class A:
    def do_something(self):
        pass

class B:
    def do_something(self):
        pass

class C(A, B):
    pass

Multilevel Inheritance: In multilevel inheritance, a subclass inherits from a superclass, which itself inherits from another superclass. For example:
class A:
    def do_something(self):
        pass

class B(A):
    pass

class C(B):
    pass

Hierarchical Inheritance: In hierarchical inheritance, two or more subclasses inherit from a single superclass. For example:
class Animal:
    def __init__(self, name):
        self.name = name
        
    def speak(self):
        pass

class Dog(Animal):
    def speak(self):
        return "Woof!"

class Cat(Animal):
    def speak(self):
        return "Meow!"

class Cow(Animal):
    def speak(self):
        return "Moo!"

Hybrid Inheritance: Inheritance consisting of multiple types of inheritance is called hybrid inheritance.
# Python program to demonstrate
# hybrid inheritance


class School:
	def func1(self):
		print("This function is in school.")


class Student1(School):
	def func2(self):
		print("This function is in student 1. ")


class Student2(School):
	def func3(self):
		print("This function is in student 2.")


class Student3(Student1, School):
	def func4(self):
		print("This function is in student 3.")


# Driver's code
object = Student3()
object.func1()
object.func2()
